# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
data = pd.read_csv('../data/subjects-xy/subject15_1.csv', delimiter=";")
data.shape
# Out:
# (3468, 18)

# %%
data.head(5)
# Out:
#        Timestamp  Lap_Number  Position.x.  Position.y.  Position.z.  \
# 0  1683320367949           0       -255.4     347.5002    -178.5393
# 1  1683320367966           0       -255.4     347.5168    -178.0287
# 2  1683320367982           0       -255.4     347.5318    -177.4959
# 3  1683320368000           0       -255.4     347.5453    -176.9416
# 4  1683320368016           0       -255.4     347.5575    -176.3668
#
#    Orientation.x.  Orientation.y.  Orientation.z.  Path_Deviation  \
# 0        1.392695        0.000000             0.0          1.2098
# 1        1.535663       -0.002307             0.0          1.1320
# 2        1.681299      359.986500             0.0          1.0508
# 3        1.829146      359.956600             0.0          0.9663
# 4        1.978781      359.896800             0.0          0.8787
#
#    Estimated_Path_Center.x.  Estimated_Path_Center.y.  \
# 0                 -254.2043                  244.2661
# 1                 -254.2812                  244.3074
# 2                 -254.3615                  244.3481
# 3                 -254.4450                  244.3904
# 4                 -254.5316                  244.4342
#
#    Estimated_Path_Center.z.  Gaze_Location.x.  Gaze_Location.y.  \
# 0                 -178.3549       -236.497650        321.242427
# 1                 -177.8562       -230.536000        320.351846
# 2                 -177.3357       -224.574350        319.461266
# 3                 -176.7943       -217.741936        318.205011
# 4                 -176.2328       -210.909521        316.948755
#
#    Gaze_Location.z.  Subject   Gaze.x.   Gaze.y.
# 0          6.570643       15  1317.764  357.2435
# 1          8.853700       15  1329.105  356.0506
# 2         11.136757       15  1340.190  354.8846
# 3         13.536593       15  1352.697  353.0272
# 4         15.936429       15  1364.924  351.2115

# %%
data2 = pd.read_csv('../data/subjects-xy/subject14_1.csv', delimiter=";")
data.head(5)
# Out:
#        Timestamp  Lap_Number  Position.x.  Position.y.  Position.z.  \
# 0  1683320367949           0       -255.4     347.5002    -178.5393
# 1  1683320367966           0       -255.4     347.5168    -178.0287
# 2  1683320367982           0       -255.4     347.5318    -177.4959
# 3  1683320368000           0       -255.4     347.5453    -176.9416
# 4  1683320368016           0       -255.4     347.5575    -176.3668
#
#    Orientation.x.  Orientation.y.  Orientation.z.  Path_Deviation  \
# 0        1.392695        0.000000             0.0          1.2098
# 1        1.535663       -0.002307             0.0          1.1320
# 2        1.681299      359.986500             0.0          1.0508
# 3        1.829146      359.956600             0.0          0.9663
# 4        1.978781      359.896800             0.0          0.8787
#
#    Estimated_Path_Center.x.  Estimated_Path_Center.y.  \
# 0                 -254.2043                  244.2661
# 1                 -254.2812                  244.3074
# 2                 -254.3615                  244.3481
# 3                 -254.4450                  244.3904
# 4                 -254.5316                  244.4342
#
#    Estimated_Path_Center.z.  Gaze_Location.x.  Gaze_Location.y.  \
# 0                 -178.3549       -236.497650        321.242427
# 1                 -177.8562       -230.536000        320.351846
# 2                 -177.3357       -224.574350        319.461266
# 3                 -176.7943       -217.741936        318.205011
# 4                 -176.2328       -210.909521        316.948755
#
#    Gaze_Location.z.  Subject   Gaze.x.   Gaze.y.
# 0          6.570643       15  1317.764  357.2435
# 1          8.853700       15  1329.105  356.0506
# 2         11.136757       15  1340.190  354.8846
# 3         13.536593       15  1352.697  353.0272
# 4         15.936429       15  1364.924  351.2115

# %%
position = data.iloc[:,2:5].to_numpy()
position.shape
# Out:
# (3468, 3)

# %%
sns.lineplot(x=position[:,0], y=position[:,2], sort=False)
# Out:
# <Axes: >

# %%
def read_data_from_subjects():
    dataset = []
    folder = '../data/subjects-xy/'
    files = os.listdir(folder)

    for f in files:
        data = pd.read_csv(folder + f, delimiter=";").to_numpy()
        positions = data[:,[2, 4]]
        dataset.append(positions)

    return dataset

# %%
dataset = read_data_from_subjects()

# %%
def plot_trajectories(optimal_path, real_path):
    f, ax = plt.subplots(1, 1, figsize=(10, 8))

    for i in range(int(len(real_path) / 2)):
        ax = sns.lineplot(
            x=real_path[i*2][:,0], 
            y=real_path[i*2][:,1], 
            sort=False, 
            color="gray", linewidth=0.25
        )

    ax = sns.lineplot(x=optimal_path[:,0], y=optimal_path[:,1], sort=False, color="maroon")

# %%
optimal_path = pd.read_csv('../data/trajectories/optimal_path.csv', delimiter=";").to_numpy()
optimal_heading = pd.read_csv('../data/trajectories/optimal_heading.csv', delimiter=";").to_numpy()

# %%
optimal_heading[0:5]
# Out:
# array([[-0.105598,  0.994409],
#        [-0.107282,  0.994229],
#        [-0.108977,  0.994044],
#        [-0.110682,  0.993856],
#        [-0.112397,  0.993663]])

# %%
angles = np.angle(optimal_heading[:,0] + optimal_heading[:,1] * 1j)
angles
# Out:
# array([1.67659156, 1.67828515, 1.67999022, ..., 1.61051178, 1.6111713 ,
#        1.61180483])

# %%
sns.histplot(angles, bins=50)
# Out:
# <Axes: ylabel='Count'>

# %%
optimal_path.shape[0] == optimal_heading.shape[0]
# Out:
# True

# %%
plot_trajectories(optimal_path, dataset)

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 8))
ax = sns.lineplot(x=optimal_path[:,0], y=optimal_path[:,1], sort=False)

# %%
sample_data = pd.read_csv('../data/subjects-xy/subject3_1.csv', delimiter=";")

# %%
sample_data.head(5)
# Out:
#        Timestamp  Lap_Number  Position.x.  Position.y.  Position.z.  \
# 0  1681827797703           0       -255.4     347.2259    -182.4447
# 1  1681827797720           0       -255.4     347.2675    -182.2537
# 2  1681827797736           0       -255.4     347.3056    -182.0298
# 3  1681827797753           0       -255.4     347.3404    -181.7739
# 4  1681827797770           0       -255.4     347.3720    -181.4870
#
#    Orientation.x.  Orientation.y.  Orientation.z.  Path_Deviation  \
# 0        0.155342             0.0             0.0          1.8052
# 1        0.223266             0.0             0.0          1.7761
# 2        0.302043             0.0             0.0          1.7419
# 3        0.390675             0.0             0.0          1.7029
# 4        0.488227             0.0             0.0          1.6592
#
#    Estimated_Path_Center.x.  Estimated_Path_Center.y.  \
# 0                 -253.6159                  243.8401
# 1                 -253.6447                  243.8605
# 2                 -253.6784                  243.8844
# 3                 -253.7170                  243.9149
# 4                 -253.7602                  243.9506
#
#    Estimated_Path_Center.z.  Gaze_Location.x.  Gaze_Location.y.  \
# 0                 -182.1695         -292.2738        357.403943
# 1                 -181.9830         -273.2335        354.166250
# 2                 -181.7643         -273.2335        354.166250
# 3                 -181.5143         -273.2335        354.166250
# 4                 -181.2341         -273.2335        354.166250
#
#    Gaze_Location.z.  Subject   Gaze.x.   Gaze.y.
# 0        247.076529        3  1249.391  411.9185
# 1        168.754000        3  1261.874  410.4857
# 2        168.754000        3  1261.874  410.4857
# 3        168.754000        3  1261.874  410.4857
# 4        168.754000        3  1261.874  410.4857

# %%
sample_path = sample_data.iloc[:,[2, 4]].to_numpy()

# %%
estimated_path = sample_data.iloc[:,[11, 12]].to_numpy()

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.lineplot(x=sample_path[:,0], y=sample_path[:,1], sort=False)
sns.lineplot(x=optimal_path[:,0], y=optimal_path[:,1], sort=False)
# Out:
# <Axes: >

# %%
from dtw import *

timewarp = dtw(optimal_path, sample_path, keep_internals=True)
timewarp.plot(type="threeway")
# Out:
# <Axes: >

# %% [markdown]
# ## List of parameters and their meanings
#
#
# | Symbol | Name | Description |
# | --- | --- | --- |
# | $t$ | Timestamp | Timestamp for the flied trajectory |
# | $\mathbf{x}$ | Position.x./y./z. | Position of the drone |
# | $\theta$ | Orientation.x./y./z. | Orientation of the drone |
# | $P$ | Collision\_Target | Point for the collision |
# | $\Delta$ | Path\_Deviation | Deviation from the path |
# | $p$ | gaze\_point\_3d\_y | Point of gaze in screen coordinates |
