# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as back
from fitter import Fitter, get_common_distributions, get_distributions
# Out:
# 2024-04-29 20:09:13.188798: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-29 20:09:13.189286: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-29 20:09:13.191871: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-29 20:09:13.221178: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 20:09:13.877244: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# First, the cleaned data is read in from the csv. There are 15 subjects, who each performed 10 laps through 32 gates. X-Y gaze position was measured at every frame. Relative angular position between drone heading vector and gate normal vector were also calculated (I will refer to this as heading for ease). We want to identify the relationship between gaze position and heading.

# %%
ang = pd.read_csv('data/full_data2.csv', usecols=['Ang_Pos'], sep=';')
gaze = pd.read_csv('data/full_data2.csv', usecols=['Gaze.x.', 'Gaze.y.'], sep=';')

ang = ang.dropna()
gaze = gaze.dropna()

# %% [markdown]
# Then, the data is randomly split into train/test portions.

# %%
ang_train, ang_test, gaze_train, gaze_test = train_test_split(ang, gaze, test_size=0.33)

ang_train = ang_train.astype(np.float32)
ang_test = ang_test.astype(np.float32)

gaze_train = gaze_train.astype(np.float32)
gaze_test = gaze_test.astype(np.float32)

# %%
ang_train.shape, gaze_train.shape
# Out:
# ((130487, 1), (130487, 2))

# %% [markdown]
# RELU was the best activation for the structure of our data, and the structure of the model was determined via tweaking to overcome the plateau at ~5.5 RMSE.
#
# Adam is a widely useful optimizer and mean_squared_error is the most appropriate regression loss function. The learning rate was reduced to minimize chances of plateauing at a local minimum.

# %%
gh_model = keras.Sequential([
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dropout(0.1),
    
    keras.layers.Dense(1, activation='relu')
])

# Compile 
gh_model.compile(optimizer=keras.optimizers.Adam(1e-3), loss='mean_squared_error', metrics=[keras.metrics.RootMeanSquaredError()])

h = gh_model.fit(gaze_train, ang_train, batch_size=64, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 2s 498us/step - loss: 559.3212 - root_mean_squared_error: 20.1772 - val_loss: 28.1686 - val_root_mean_squared_error: 5.3078
# Epoch 2/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 429us/step - loss: 31.3643 - root_mean_squared_error: 5.5998 - val_loss: 28.1686 - val_root_mean_squared_error: 5.3078
# Epoch 3/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 432us/step - loss: 29.7616 - root_mean_squared_error: 5.4538 - val_loss: 28.1686 - val_root_mean_squared_error: 5.3078
# Epoch 4/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 421us/step - loss: 29.2466 - root_mean_squared_error: 5.4078 - val_loss: 28.1686 - val_root_mean_squared_error: 5.3078
# Epoch 5/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - loss: 23.9347 - root_mean_squared_error: 4.8792 - val_loss: 12.2553 - val_root_mean_squared_error: 3.5011
# Epoch 6/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 422us/step - loss: 14.3507 - root_mean_squared_error: 3.7879 - val_loss: 11.8402 - val_root_mean_squared_error: 3.4413
# Epoch 7/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - loss: 13.3955 - root_mean_squared_error: 3.6598 - val_loss: 11.5929 - val_root_mean_squared_error: 3.4052
# Epoch 8/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 433us/step - loss: 12.8678 - root_mean_squared_error: 3.5864 - val_loss: 11.5716 - val_root_mean_squared_error: 3.4021
# Epoch 9/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 446us/step - loss: 12.7239 - root_mean_squared_error: 3.5665 - val_loss: 11.5719 - val_root_mean_squared_error: 3.4021
# Epoch 10/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 446us/step - loss: 13.0678 - root_mean_squared_error: 3.6147 - val_loss: 11.4912 - val_root_mean_squared_error: 3.3902
# Epoch 11/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 435us/step - loss: 13.0507 - root_mean_squared_error: 3.6121 - val_loss: 11.5157 - val_root_mean_squared_error: 3.3938
# Epoch 12/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 454us/step - loss: 12.9421 - root_mean_squared_error: 3.5968 - val_loss: 11.4546 - val_root_mean_squared_error: 3.3848
# Epoch 13/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 427us/step - loss: 13.1671 - root_mean_squared_error: 3.6280 - val_loss: 11.4682 - val_root_mean_squared_error: 3.3868
# Epoch 14/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 438us/step - loss: 12.9880 - root_mean_squared_error: 3.6035 - val_loss: 11.4592 - val_root_mean_squared_error: 3.3855
# Epoch 15/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 452us/step - loss: 12.7113 - root_mean_squared_error: 3.5648 - val_loss: 11.4535 - val_root_mean_squared_error: 3.3846
# Epoch 16/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 446us/step - loss: 12.9375 - root_mean_squared_error: 3.5963 - val_loss: 11.4662 - val_root_mean_squared_error: 3.3865
# Epoch 17/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 447us/step - loss: 12.9869 - root_mean_squared_error: 3.6035 - val_loss: 11.4604 - val_root_mean_squared_error: 3.3857
# Epoch 18/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 426us/step - loss: 13.2457 - root_mean_squared_error: 3.6390 - val_loss: 11.4403 - val_root_mean_squared_error: 3.3827
# Epoch 19/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - loss: 12.2915 - root_mean_squared_error: 3.5050 - val_loss: 11.5069 - val_root_mean_squared_error: 3.3925
# Epoch 20/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 454us/step - loss: 12.4107 - root_mean_squared_error: 3.5216 - val_loss: 11.4502 - val_root_mean_squared_error: 3.3841
# Epoch 21/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 432us/step - loss: 12.8989 - root_mean_squared_error: 3.5896 - val_loss: 11.4753 - val_root_mean_squared_error: 3.3879
# Epoch 22/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 422us/step - loss: 12.4915 - root_mean_squared_error: 3.5333 - val_loss: 11.4952 - val_root_mean_squared_error: 3.3908
# Epoch 23/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step - loss: 12.8926 - root_mean_squared_error: 3.5901 - val_loss: 11.4629 - val_root_mean_squared_error: 3.3860
# Epoch 24/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 437us/step - loss: 12.8146 - root_mean_squared_error: 3.5795 - val_loss: 11.4661 - val_root_mean_squared_error: 3.3865
# Epoch 25/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 425us/step - loss: 12.8767 - root_mean_squared_error: 3.5879 - val_loss: 11.4927 - val_root_mean_squared_error: 3.3904
# Epoch 26/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 455us/step - loss: 13.1516 - root_mean_squared_error: 3.6261 - val_loss: 11.4400 - val_root_mean_squared_error: 3.3826
# Epoch 27/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - loss: 12.9541 - root_mean_squared_error: 3.5984 - val_loss: 11.4581 - val_root_mean_squared_error: 3.3853
# Epoch 28/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 418us/step - loss: 13.2114 - root_mean_squared_error: 3.6346 - val_loss: 11.4624 - val_root_mean_squared_error: 3.3860
# Epoch 29/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 417us/step - loss: 12.7129 - root_mean_squared_error: 3.5649 - val_loss: 11.4566 - val_root_mean_squared_error: 3.3851
# Epoch 30/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 430us/step - loss: 12.5169 - root_mean_squared_error: 3.5372 - val_loss: 11.4822 - val_root_mean_squared_error: 3.3889
# Epoch 31/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 426us/step - loss: 12.7283 - root_mean_squared_error: 3.5671 - val_loss: 11.4313 - val_root_mean_squared_error: 3.3813
# Epoch 32/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - loss: 12.5811 - root_mean_squared_error: 3.5466 - val_loss: 11.4591 - val_root_mean_squared_error: 3.3855
# Epoch 33/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 425us/step - loss: 13.0616 - root_mean_squared_error: 3.6135 - val_loss: 11.4261 - val_root_mean_squared_error: 3.3806
# Epoch 34/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 438us/step - loss: 12.6085 - root_mean_squared_error: 3.5501 - val_loss: 11.4409 - val_root_mean_squared_error: 3.3828
# Epoch 35/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 425us/step - loss: 13.0622 - root_mean_squared_error: 3.6137 - val_loss: 11.4267 - val_root_mean_squared_error: 3.3807
# Epoch 36/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 422us/step - loss: 12.8424 - root_mean_squared_error: 3.5832 - val_loss: 11.4400 - val_root_mean_squared_error: 3.3826
# Epoch 37/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 411us/step - loss: 12.5783 - root_mean_squared_error: 3.5455 - val_loss: 11.4615 - val_root_mean_squared_error: 3.3858
# Epoch 38/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 483us/step - loss: 13.0326 - root_mean_squared_error: 3.6095 - val_loss: 11.4976 - val_root_mean_squared_error: 3.3912
# Epoch 39/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 461us/step - loss: 12.9871 - root_mean_squared_error: 3.6034 - val_loss: 11.4488 - val_root_mean_squared_error: 3.3839
# Epoch 40/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 440us/step - loss: 12.7660 - root_mean_squared_error: 3.5722 - val_loss: 11.4256 - val_root_mean_squared_error: 3.3805
# Epoch 41/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 423us/step - loss: 12.9556 - root_mean_squared_error: 3.5991 - val_loss: 11.4238 - val_root_mean_squared_error: 3.3802
# Epoch 42/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 443us/step - loss: 12.3442 - root_mean_squared_error: 3.5128 - val_loss: 11.4531 - val_root_mean_squared_error: 3.3846
# Epoch 43/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 440us/step - loss: 12.8716 - root_mean_squared_error: 3.5872 - val_loss: 11.4507 - val_root_mean_squared_error: 3.3842
# Epoch 44/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 442us/step - loss: 12.8781 - root_mean_squared_error: 3.5878 - val_loss: 11.4384 - val_root_mean_squared_error: 3.3824
# Epoch 45/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 422us/step - loss: 12.7264 - root_mean_squared_error: 3.5670 - val_loss: 11.4561 - val_root_mean_squared_error: 3.3850
# Epoch 46/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 434us/step - loss: 13.0150 - root_mean_squared_error: 3.6067 - val_loss: 11.4330 - val_root_mean_squared_error: 3.3816
# Epoch 47/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 429us/step - loss: 13.0466 - root_mean_squared_error: 3.6113 - val_loss: 11.4824 - val_root_mean_squared_error: 3.3889
# Epoch 48/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 433us/step - loss: 12.8798 - root_mean_squared_error: 3.5878 - val_loss: 11.4604 - val_root_mean_squared_error: 3.3857
# Epoch 49/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 452us/step - loss: 12.9293 - root_mean_squared_error: 3.5946 - val_loss: 11.4614 - val_root_mean_squared_error: 3.3858
# Epoch 50/50
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 436us/step - loss: 12.9758 - root_mean_squared_error: 3.6018 - val_loss: 11.4437 - val_root_mean_squared_error: 3.3832

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(range(50), h.history['val_loss'], 'o-', color='maroon', label='Validation')
ax.plot(range(50), h.history['loss'], 'o-', color='black', label='Training')
ax.set_xlabel('Epoch')
#ax.set_ylim(0, 50)
ax.legend()
ax.set_title('Loss Trajectory')
sns.despine(ax=ax)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(range(50), h.history['val_root_mean_squared_error'], 'o-', color='maroon', label='Validation')
ax.plot(range(50), h.history['root_mean_squared_error'], 'o-', color='black', label='Training')
ax.set_xlabel('Epoch')
#ax.set_ylim(0, 10)
ax.legend()
ax.set_title('Accuracy Trajectory')
sns.despine(ax=ax)

# %%
test_loss, test_accuracy = model.evaluate(gaze_test, ang_test)
# Out:
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 0s 228us/step - loss: 28.8817 - root_mean_squared_error: 5.3736

# %% [markdown]
# In the interest of using this data to inform our likelihood, sample predictions were used to generate a distribution of possible "headings" (relative angular positions).

# %%
pred = gh_model.predict(gaze_test)
# Out:
# 2009/2009 ━━━━━━━━━━━━━━━━━━━━ 1s 401us/step

# %%
pred.min(), pred.max()
# Out:
# (3.6184723, 8.867556)

# %%
ang_test.Ang_Pos.min(), ang_test.Ang_Pos.max()
# Out:
# (-2.3804728984832764, 76.38558959960938)

# %% [markdown]
# The data is plotted to get an idea of the rel-ang-position relative frequencies.

# %%
#sns.displot(data=pred, kind="hist", bins = 100, aspect = 1.5)
#plt.xlim(left=0, right=5)

sns.histplot(
    pred, color='#AA0000', alpha=0.8, lw=2, label=f'Predicted')
sns.histplot(
    ang_test.Ang_Pos, color='#0000AA', alpha=0.8, lw=2, label=f'Actual')
plt.xlim(left=0, right=15)
# Out:
# (0.0, 15.0)

# %%
plt.scatter(ang_test, pred)

# %% [markdown]
# We also attempted to train a model to predict heading based on gaze, but this was not effective.

# %%
hg_model = keras.Sequential([
    keras.layers.Dense(8, activation='relu'),
    #keras.layers.Dropout(0.1),
    keras.layers.Dense(16, activation='relu'),
    #keras.layers.Dropout(0.1),
    keras.layers.Dense(8, activation='relu'),
    #keras.layers.Dropout(0.1),
    
    keras.layers.Dense(2, activation='relu')
])

# Compile 
hg_model.compile(optimizer=keras.optimizers.Adam(1e-3), loss='mean_squared_error', metrics=[keras.metrics.RootMeanSquaredError()])

g = hg_model.fit(ang_train, gaze_train, batch_size=64, epochs=100, validation_split=0.1)
# Out:
# Epoch 1/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 393us/step - loss: 651123.5000 - root_mean_squared_error: 792.6710 - val_loss: 79931.0781 - val_root_mean_squared_error: 282.7344
# Epoch 2/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - loss: 81712.2891 - root_mean_squared_error: 285.8421 - val_loss: 78852.1250 - val_root_mean_squared_error: 280.8168
# Epoch 3/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 381us/step - loss: 81173.2422 - root_mean_squared_error: 284.9066 - val_loss: 78803.2031 - val_root_mean_squared_error: 280.7292
# Epoch 4/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - loss: 81095.8594 - root_mean_squared_error: 284.7719 - val_loss: 78795.9922 - val_root_mean_squared_error: 280.7160
# Epoch 5/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - loss: 81055.3828 - root_mean_squared_error: 284.6994 - val_loss: 78702.6094 - val_root_mean_squared_error: 280.5503
# Epoch 6/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 361us/step - loss: 81424.2734 - root_mean_squared_error: 285.3378 - val_loss: 79011.6562 - val_root_mean_squared_error: 281.1006
# Epoch 7/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 368us/step - loss: 81165.0938 - root_mean_squared_error: 284.8936 - val_loss: 78692.7891 - val_root_mean_squared_error: 280.5328
# Epoch 8/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 81130.7422 - root_mean_squared_error: 284.8321 - val_loss: 78698.3750 - val_root_mean_squared_error: 280.5433
# Epoch 9/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 360us/step - loss: 81110.6328 - root_mean_squared_error: 284.7945 - val_loss: 78892.3125 - val_root_mean_squared_error: 280.8900
# Epoch 10/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 354us/step - loss: 81150.5703 - root_mean_squared_error: 284.8668 - val_loss: 78690.7344 - val_root_mean_squared_error: 280.5297
# Epoch 11/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - loss: 80380.2344 - root_mean_squared_error: 283.5080 - val_loss: 78877.7344 - val_root_mean_squared_error: 280.8616
# Epoch 12/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 80942.5469 - root_mean_squared_error: 284.5016 - val_loss: 78888.6406 - val_root_mean_squared_error: 280.8806
# Epoch 13/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - loss: 80863.9844 - root_mean_squared_error: 284.3636 - val_loss: 78631.2891 - val_root_mean_squared_error: 280.4232
# Epoch 14/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - loss: 81518.1406 - root_mean_squared_error: 285.5096 - val_loss: 78738.7422 - val_root_mean_squared_error: 280.6162
# Epoch 15/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 81193.9844 - root_mean_squared_error: 284.9337 - val_loss: 78632.7734 - val_root_mean_squared_error: 280.4260
# Epoch 16/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - loss: 81009.8359 - root_mean_squared_error: 284.6159 - val_loss: 78690.0391 - val_root_mean_squared_error: 280.5276
# Epoch 17/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - loss: 81839.8672 - root_mean_squared_error: 286.0680 - val_loss: 78611.4453 - val_root_mean_squared_error: 280.3884
# Epoch 18/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 362us/step - loss: 80921.0625 - root_mean_squared_error: 284.4637 - val_loss: 79037.3125 - val_root_mean_squared_error: 281.1448
# Epoch 19/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 373us/step - loss: 81672.7266 - root_mean_squared_error: 285.7787 - val_loss: 78638.0859 - val_root_mean_squared_error: 280.4350
# Epoch 20/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 373us/step - loss: 81178.0781 - root_mean_squared_error: 284.9148 - val_loss: 78651.5859 - val_root_mean_squared_error: 280.4603
# Epoch 21/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - loss: 80616.9062 - root_mean_squared_error: 283.9298 - val_loss: 78741.1016 - val_root_mean_squared_error: 280.6201
# Epoch 22/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 81004.9531 - root_mean_squared_error: 284.6116 - val_loss: 78941.2188 - val_root_mean_squared_error: 280.9739
# Epoch 23/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - loss: 80859.1328 - root_mean_squared_error: 284.3542 - val_loss: 78790.9297 - val_root_mean_squared_error: 280.7093
# Epoch 24/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 362us/step - loss: 80593.8750 - root_mean_squared_error: 283.8885 - val_loss: 78865.3281 - val_root_mean_squared_error: 280.8391
# Epoch 25/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - loss: 80989.4766 - root_mean_squared_error: 284.5796 - val_loss: 78599.6250 - val_root_mean_squared_error: 280.3669
# Epoch 26/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - loss: 80281.1094 - root_mean_squared_error: 283.3360 - val_loss: 78698.5078 - val_root_mean_squared_error: 280.5440
# Epoch 27/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 373us/step - loss: 80502.1875 - root_mean_squared_error: 283.7246 - val_loss: 78699.1875 - val_root_mean_squared_error: 280.5455
# Epoch 28/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - loss: 81245.2891 - root_mean_squared_error: 285.0321 - val_loss: 78845.7188 - val_root_mean_squared_error: 280.8041
# Epoch 29/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 373us/step - loss: 80880.3125 - root_mean_squared_error: 284.3899 - val_loss: 78702.8750 - val_root_mean_squared_error: 280.5502
# Epoch 30/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - loss: 80559.1484 - root_mean_squared_error: 283.8236 - val_loss: 78606.8281 - val_root_mean_squared_error: 280.3796
# Epoch 31/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - loss: 80921.2812 - root_mean_squared_error: 284.4647 - val_loss: 78895.8281 - val_root_mean_squared_error: 280.8928
# Epoch 32/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - loss: 80519.0156 - root_mean_squared_error: 283.7528 - val_loss: 78688.1094 - val_root_mean_squared_error: 280.5257
# Epoch 33/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 377us/step - loss: 81513.1328 - root_mean_squared_error: 285.5001 - val_loss: 78695.8828 - val_root_mean_squared_error: 280.5379
# Epoch 34/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 359us/step - loss: 81000.2812 - root_mean_squared_error: 284.5982 - val_loss: 78620.9297 - val_root_mean_squared_error: 280.4040
# Epoch 35/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - loss: 81361.9297 - root_mean_squared_error: 285.2359 - val_loss: 78636.3906 - val_root_mean_squared_error: 280.4318
# Epoch 36/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - loss: 81029.3984 - root_mean_squared_error: 284.6499 - val_loss: 78703.9531 - val_root_mean_squared_error: 280.5539
# Epoch 37/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - loss: 81096.4375 - root_mean_squared_error: 284.7703 - val_loss: 78701.5156 - val_root_mean_squared_error: 280.5499
# Epoch 38/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - loss: 80690.1250 - root_mean_squared_error: 284.0466 - val_loss: 78609.0938 - val_root_mean_squared_error: 280.3835
# Epoch 39/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 373us/step - loss: 80870.5859 - root_mean_squared_error: 284.3743 - val_loss: 78688.7422 - val_root_mean_squared_error: 280.5270
# Epoch 40/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - loss: 81190.8516 - root_mean_squared_error: 284.9350 - val_loss: 78611.8047 - val_root_mean_squared_error: 280.3881
# Epoch 41/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - loss: 81043.2891 - root_mean_squared_error: 284.6750 - val_loss: 78738.2734 - val_root_mean_squared_error: 280.6150
# Epoch 42/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 385us/step - loss: 80617.3516 - root_mean_squared_error: 283.9278 - val_loss: 78603.3125 - val_root_mean_squared_error: 280.3735
# Epoch 43/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 368us/step - loss: 81116.6328 - root_mean_squared_error: 284.8069 - val_loss: 78707.9688 - val_root_mean_squared_error: 280.5598
# Epoch 44/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 383us/step - loss: 81803.2422 - root_mean_squared_error: 286.0042 - val_loss: 78663.4531 - val_root_mean_squared_error: 280.4818
# Epoch 45/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 395us/step - loss: 81268.2500 - root_mean_squared_error: 285.0723 - val_loss: 78777.1406 - val_root_mean_squared_error: 280.6820
# Epoch 46/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 377us/step - loss: 81652.2891 - root_mean_squared_error: 285.7426 - val_loss: 78612.6797 - val_root_mean_squared_error: 280.3903
# Epoch 47/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - loss: 80756.0625 - root_mean_squared_error: 284.1742 - val_loss: 78654.7500 - val_root_mean_squared_error: 280.4643
# Epoch 48/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 362us/step - loss: 81219.8125 - root_mean_squared_error: 284.9858 - val_loss: 78578.2500 - val_root_mean_squared_error: 280.3288
# Epoch 49/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - loss: 81007.9453 - root_mean_squared_error: 284.6167 - val_loss: 78744.1250 - val_root_mean_squared_error: 280.6233
# Epoch 50/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 81047.6172 - root_mean_squared_error: 284.6846 - val_loss: 78634.2188 - val_root_mean_squared_error: 280.4295
# Epoch 51/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - loss: 81522.4141 - root_mean_squared_error: 285.5096 - val_loss: 78588.6875 - val_root_mean_squared_error: 280.3477
# Epoch 52/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - loss: 81781.7891 - root_mean_squared_error: 285.9720 - val_loss: 78718.4375 - val_root_mean_squared_error: 280.5799
# Epoch 53/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 369us/step - loss: 81161.8438 - root_mean_squared_error: 284.8855 - val_loss: 78558.7422 - val_root_mean_squared_error: 280.2938
# Epoch 54/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 81454.3516 - root_mean_squared_error: 285.3991 - val_loss: 78605.2188 - val_root_mean_squared_error: 280.3760
# Epoch 55/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - loss: 81212.3516 - root_mean_squared_error: 284.9759 - val_loss: 78607.2031 - val_root_mean_squared_error: 280.3800
# Epoch 56/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 369us/step - loss: 80876.6875 - root_mean_squared_error: 284.3852 - val_loss: 78600.5703 - val_root_mean_squared_error: 280.3683
# Epoch 57/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 80782.8750 - root_mean_squared_error: 284.2164 - val_loss: 78679.6094 - val_root_mean_squared_error: 280.5106
# Epoch 58/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 383us/step - loss: 81028.3828 - root_mean_squared_error: 284.6495 - val_loss: 78555.3750 - val_root_mean_squared_error: 280.2877
# Epoch 59/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - loss: 80560.1484 - root_mean_squared_error: 283.8284 - val_loss: 78623.7500 - val_root_mean_squared_error: 280.4098
# Epoch 60/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 361us/step - loss: 81090.3047 - root_mean_squared_error: 284.7591 - val_loss: 78638.3047 - val_root_mean_squared_error: 280.4367
# Epoch 61/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - loss: 80160.1484 - root_mean_squared_error: 283.1147 - val_loss: 78801.3984 - val_root_mean_squared_error: 280.7283
# Epoch 62/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 385us/step - loss: 80715.3125 - root_mean_squared_error: 284.0964 - val_loss: 78604.3594 - val_root_mean_squared_error: 280.3747
# Epoch 63/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - loss: 81761.6562 - root_mean_squared_error: 285.9347 - val_loss: 78561.3125 - val_root_mean_squared_error: 280.2989
# Epoch 64/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 378us/step - loss: 80537.4062 - root_mean_squared_error: 283.7865 - val_loss: 78569.9844 - val_root_mean_squared_error: 280.3140
# Epoch 65/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - loss: 80621.5312 - root_mean_squared_error: 283.9333 - val_loss: 78599.1094 - val_root_mean_squared_error: 280.3661
# Epoch 66/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 81036.6562 - root_mean_squared_error: 284.6635 - val_loss: 78613.2969 - val_root_mean_squared_error: 280.3915
# Epoch 67/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - loss: 81510.8594 - root_mean_squared_error: 285.4943 - val_loss: 78585.3359 - val_root_mean_squared_error: 280.3419
# Epoch 68/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 357us/step - loss: 80870.1328 - root_mean_squared_error: 284.3752 - val_loss: 78699.1562 - val_root_mean_squared_error: 280.5457
# Epoch 69/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 362us/step - loss: 81138.0547 - root_mean_squared_error: 284.8455 - val_loss: 78551.8594 - val_root_mean_squared_error: 280.2817
# Epoch 70/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 380us/step - loss: 80760.5391 - root_mean_squared_error: 284.1796 - val_loss: 78641.6406 - val_root_mean_squared_error: 280.4410
# Epoch 71/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - loss: 80893.6562 - root_mean_squared_error: 284.4151 - val_loss: 78564.3047 - val_root_mean_squared_error: 280.3042
# Epoch 72/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 369us/step - loss: 80336.7969 - root_mean_squared_error: 283.4323 - val_loss: 78594.9141 - val_root_mean_squared_error: 280.3580
# Epoch 73/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - loss: 81138.9688 - root_mean_squared_error: 284.8470 - val_loss: 78600.4609 - val_root_mean_squared_error: 280.3692
# Epoch 74/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - loss: 81180.6797 - root_mean_squared_error: 284.9196 - val_loss: 78569.4688 - val_root_mean_squared_error: 280.3130
# Epoch 75/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 369us/step - loss: 79953.7188 - root_mean_squared_error: 282.7557 - val_loss: 78562.8906 - val_root_mean_squared_error: 280.3011
# Epoch 76/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - loss: 80856.6172 - root_mean_squared_error: 284.3447 - val_loss: 78557.5234 - val_root_mean_squared_error: 280.2913
# Epoch 77/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 80850.5547 - root_mean_squared_error: 284.3394 - val_loss: 78693.2109 - val_root_mean_squared_error: 280.5349
# Epoch 78/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - loss: 80859.1641 - root_mean_squared_error: 284.3548 - val_loss: 78564.2266 - val_root_mean_squared_error: 280.3039
# Epoch 79/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - loss: 81097.6797 - root_mean_squared_error: 284.7705 - val_loss: 78695.6875 - val_root_mean_squared_error: 280.5370
# Epoch 80/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - loss: 81083.4141 - root_mean_squared_error: 284.7492 - val_loss: 78577.3281 - val_root_mean_squared_error: 280.3271
# Epoch 81/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - loss: 80955.9219 - root_mean_squared_error: 284.5233 - val_loss: 78599.1172 - val_root_mean_squared_error: 280.3654
# Epoch 82/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 356us/step - loss: 81459.7812 - root_mean_squared_error: 285.4070 - val_loss: 78551.7578 - val_root_mean_squared_error: 280.2819
# Epoch 83/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 371us/step - loss: 80666.4297 - root_mean_squared_error: 284.0149 - val_loss: 78573.9922 - val_root_mean_squared_error: 280.3208
# Epoch 84/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - loss: 80681.0078 - root_mean_squared_error: 284.0390 - val_loss: 78550.2500 - val_root_mean_squared_error: 280.2790
# Epoch 85/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - loss: 81199.1406 - root_mean_squared_error: 284.9509 - val_loss: 78575.8516 - val_root_mean_squared_error: 280.3242
# Epoch 86/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 382us/step - loss: 81329.2109 - root_mean_squared_error: 285.1805 - val_loss: 78618.2734 - val_root_mean_squared_error: 280.4009
# Epoch 87/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - loss: 81502.4375 - root_mean_squared_error: 285.4802 - val_loss: 78594.2422 - val_root_mean_squared_error: 280.3565
# Epoch 88/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 380us/step - loss: 81176.6797 - root_mean_squared_error: 284.9121 - val_loss: 78744.1250 - val_root_mean_squared_error: 280.6259
# Epoch 89/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 387us/step - loss: 80981.1797 - root_mean_squared_error: 284.5683 - val_loss: 78591.6641 - val_root_mean_squared_error: 280.3521
# Epoch 90/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 399us/step - loss: 81119.8594 - root_mean_squared_error: 284.8048 - val_loss: 78557.4531 - val_root_mean_squared_error: 280.2912
# Epoch 91/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 380us/step - loss: 80841.2656 - root_mean_squared_error: 284.3232 - val_loss: 78605.9844 - val_root_mean_squared_error: 280.3792
# Epoch 92/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 374us/step - loss: 81826.8750 - root_mean_squared_error: 286.0484 - val_loss: 78552.3125 - val_root_mean_squared_error: 280.2831
# Epoch 93/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - loss: 80351.4141 - root_mean_squared_error: 283.4447 - val_loss: 78647.2109 - val_root_mean_squared_error: 280.4529
# Epoch 94/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 375us/step - loss: 81212.0938 - root_mean_squared_error: 284.9746 - val_loss: 78533.4062 - val_root_mean_squared_error: 280.2491
# Epoch 95/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 389us/step - loss: 80620.2500 - root_mean_squared_error: 283.9331 - val_loss: 78547.1719 - val_root_mean_squared_error: 280.2739
# Epoch 96/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - loss: 80088.9297 - root_mean_squared_error: 282.9897 - val_loss: 78574.3594 - val_root_mean_squared_error: 280.3225
# Epoch 97/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - loss: 81577.6953 - root_mean_squared_error: 285.6134 - val_loss: 78541.1406 - val_root_mean_squared_error: 280.2626
# Epoch 98/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 372us/step - loss: 81248.8672 - root_mean_squared_error: 285.0402 - val_loss: 78616.9375 - val_root_mean_squared_error: 280.3971
# Epoch 99/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 375us/step - loss: 81378.6094 - root_mean_squared_error: 285.2667 - val_loss: 78627.7969 - val_root_mean_squared_error: 280.4183
# Epoch 100/100
# 1835/1835 ━━━━━━━━━━━━━━━━━━━━ 1s 368us/step - loss: 81064.0234 - root_mean_squared_error: 284.7098 - val_loss: 78785.6875 - val_root_mean_squared_error: 280.7002

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.plot(range(100), g.history['val_loss'], 'o-', color='maroon', label='Validation')
ax.plot(range(100), g.history['loss'], 'o-', color='black', label='Training')
ax.set_xlabel('Epoch')
#ax.set_ylabel('Percentage error')
ax.legend()
ax.set_title('Loss Trajectory')
sns.despine(ax=ax)

# %%
test_loss, test_accuracy = hg_model.evaluate(ang_test, gaze_test)
# Out:
# 2240/2240 ━━━━━━━━━━━━━━━━━━━━ 2s 688us/step - loss: 82.0181 - mean_absolute_percentage_error: 82.0181

# %%
test_loss, test_accuracy
# Out:
# (75.42182922363281, 75.44270324707031)
